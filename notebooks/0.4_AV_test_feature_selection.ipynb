# %%
# !which python
# Out:
# /home/fuchsfl/anaconda3/envs/data_science_for_buisness/bin/python

# %%
# !conda install pandas -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/fuchsfl/anaconda3/envs/data_science_for_buisness
#
#   added / updated specs:
#     - pandas
#
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2019.4-243
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   mkl                pkgs/main/linux-64::mkl-2019.4-243
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py37he904b0f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.0.14-py37ha843d7b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.0-py37hd6b4f25_0
#   numpy              pkgs/main/linux-64::numpy-1.17.2-py37haad9e8e_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.17.2-py37hde5b4d6_0
#   pandas             pkgs/main/linux-64::pandas-0.25.2-py37he6710b0_0
#   pytz               pkgs/main/noarch::pytz-2019.3-py_0
#
#
# ...

# %%
# !conda install numpy -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /mnt/c/Users/fuchsfl/Documents/data_science_for_business_lmu/notebooks

# %%
os.chdir('..')

# %%
from src.features.build_features import FeatureEngineering

# %%
from src.data.make_dataset import get_preprocessed_datasets

# %%
import pandas as pd
import numpy as np

# %%
df_bitcoin, df, df_test = get_preprocessed_datasets()
# Out:
# 2019-11-01 14:17:57,732 - src.data.make_dataset - INFO - making final data sets from raw data
# 2019-11-01 14:17:58,152 - src.data.make_dataset - INFO - Shape of df_bitcoin: (2355, 2)
# 2019-11-01 14:17:58,153 - src.data.make_dataset - INFO - Shape of df: (4757, 91)

# %%
# Out:
#       date_in_ms   price
# 0  1367107200000   135.3
# 1  1367193600000  141.96
# 2  1367280000000   135.3
# 3  1367366400000   117.0
# 4  1367452800000  103.43

# %%
fe = FeatureEngineering(df, df_bitcoin, df_test)

# %%
df
# Out:
#       OBS_ID                ï..id symbol                 name  \
# 0     235691               01coin    zoc               01coin
# 1     235692                   0x    zrx                   0x
# 2     235693               0xcert    zxc               0xcert
# 3     235694               0xdark    oxd               0xDark
# 4     235695            10m-token   10mt            10M Token
# ...      ...                  ...    ...                  ...
# 4752  240443  zulu-republic-token    ztx  Zulu Republic Token
# 4753  240444                 zumy    zmy                 Zumy
# 4754  240445              zurcoin    zur              Zurcoin
# 4755  240446           zuzubecoin   zube           zuzubecoin
# 4756  240447               zxflea  xflea               zXFLEA
#
#                   categories_0                            contract_address  \
# 0                  Masternodes                                         NaN
# ...

# %%
fe.normalize_categorical_feature("categories_0")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categories_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-317a878a0f7a> in <module>
# ...

# %%
fe.construct_features()
# Out:
# 2019-11-01 14:26:40,947 - src.features.build_features - INFO - Adding transaction count for train
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4a8f453fc4e0> in <module>
# ----> 1 fe.construct_features()
#
# /mnt/c/Users/fuchsfl/Documents/data_science_for_business_lmu/src/features/build_features.py in construct_features(self)
#      94     def construct_features(self):
#      95         """This function is the pipeline for adding all features to the dataset
# ---> 96         """
#      97         self._add_transaction_count(train=True)
#      98         self._add_transaction_count(train=False)
#
# /mnt/c/Users/fuchsfl/Documents/data_science_for_business_lmu/src/features/build_features.py in _add_transaction_count(self, train)
#      67
#      68         if train:
# ---> 69             self.df_features_train = pd.merge(
# ...

# %%
fe.df_features_train
# Out:
#       OBS_ID              categories_0  success  transaction_count
# 0     235691               Masternodes        0       45774.719889
# 1     235692                  Protocol        1      975773.000000
# 2     235693                  Protocol        0       22730.000000
# 3     235694                       NaN        0         125.000000
# 4     235695                       NaN        0       16417.000000
# ...      ...                       ...      ...                ...
# 4752  240443                       NaN        0       16776.000000
# 4753  240444  Internet of Things (IOT)        0       45774.719889
# 4754  240445                       NaN        0       45774.719889
# 4755  240446                       NaN        0         168.000000
# 4756  240447               Masternodes        0       45774.719889
#
# [4757 rows x 4 columns]

# %%
fe.df_features_test
# Out:
#       OBS_ID  transaction_count
# 0          1         376.000000
# 1          2       70408.000000
# 2          3       59910.102041
# 3          4         304.000000
# 4          5       59910.102041
# ...      ...                ...
# 996      997       59910.102041
# 997      998       59910.102041
# 998      999       59910.102041
# 999     1000       87780.000000
# 1000    1001       59910.102041
#
# [1001 rows x 2 columns]

# %%
df_test
# Out:
#       OBS_ID     ï..id symbol       name    categories_0  \
# 0          1  02-token    o2t   O2 Token             NaN
# 1          2    0chain    zcn     0chain             NaN
# 2          3      1337   1337      Elite             NaN
# 3          4  300token    300  300 Token             NaN
# 4          5   42-coin     42    42-coin             NaN
# ...      ...       ...    ...        ...             ...
# 996      997       zio    zio        ZIO        Gambling
# 997      998  zioncoin    znc   ZionCoin             NaN
# 998      999    zoptax    zpt     Zoptax             NaN
# 999     1000      zper    zpr       ZPER             NaN
# 1000    1001   zumcoin    zum    ZumCoin  Cryptocurrency
#
#                                 contract_address  transaction_count  \
# 0     0xb1bafca3737268a96673a250173b6ed8f1b5b65f              376.0
# 1     0xb9ef770b6a5e12e45983c5d80545258aa38f3b78            70408.0
# 2                                            NaN                NaN
# ...
