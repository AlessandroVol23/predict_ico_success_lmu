# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
res = pd.read_json('../data/results/result.json')
res = res.assign(mcc = json_normalize(res.metrics).values)
res_mcc = res[['feature_set', 'mcc']]
res_mcc = res_mcc.sort_values('mcc', ascending=False)
metas=[]
for i in res.features.values:
    metas.append(i[0])
metas_df= json_normalize(metas)
res_mcc['upsampling'] = metas_df
res_mcc
# Out:
#                        feature_set       mcc upsampling
# 0    na_less_20_median_upsample_50  0.184088        0.5
# 1    na_less_20_median_upsample_50  0.184088        0.5
# 2    na_less_20_median_upsample_75  0.184088       0.75
# 3    na_less_20_median_upsample_75  0.184088       0.75
# 4    na_less_20_median_upsample_25  0.184088       0.25
# 5   na_less_20_median_upsample_100  0.184088          1
# 6    na_less_20_median_upsample_00  0.184088        0.0
# 9             correlation_positive  0.170557        0.0
# 10        correlation_positive_u50  0.170557        0.5
# 11       correlation_positive_u100  0.170557          1
# 8             correlation_positive  0.169642        0.0
# 7             correlation_positive  0.163296        0.0
